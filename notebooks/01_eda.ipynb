# %% [markdown]
# # Ячейка 1 (Markdown)
# ## 01. Разведочный анализ данных (EDA)
# Цель: Понять формат данных, распределение классов, найти аномалии и "битые" картинки.
#
# # Ячейка 2 (Code)
# import os
# import cv2
# import matplotlib.pyplot as plt
# import pandas as pd
# import numpy as np
#
# # TODO: Указать пути к данным после получения датасета
# DATA_DIR = "../data/raw_dataset/"
#
# # Ячейка 3 (Code)
# # TODO: Загрузка метаданных (CSV/JSON/XML)
# # df = pd.read_csv(os.path.join(DATA_DIR, "labels.csv"))
# # display(df.head())
# # df['class'].value_counts().plot(kind='bar') # Проверка баланса классов
#
# # Ячейка 4 (Code)
# # TODO: Написать функцию вывода сетки 3x3 изображений вместе с разметкой
# def show_sample_grid(df, n=9):
#     """Отрисовка картинок с наложением масок/точек"""
#     pass
# # show_sample_grid(df)
#
# # Ячейка 5 (Markdown)
# **Выводы после EDA:**
# * Размер картинок: ... (разный / одинаковый)
# * Баланс классов: ... (нужна ли аугментация для редких классов?)
# * Особенности: ... (артефакты, вотермарки, засветы на рентгене)
