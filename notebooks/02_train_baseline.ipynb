# %% [markdown]
# # Ячейка 1 (Markdown)
# ## 02. Обучение Baseline модели
# Цель: За 1-2 часа получить первые веса модели (даже если метрики слабые), чтобы инженеры бэкенда могли начать интеграцию с UI.
#
# # Ячейка 2 (Code)
# import sys
# sys.path.append('..') # Для импорта модулей из нашего проекта
#
# # TODO: Импорт из папки training/
# # from training.dataset import MedicalImageDataset
# # from training.trainer import MedicalTrainer
# # from training.augmentations import get_training_augmentations
#
# # Ячейка 3 (Code)
# # TODO: Инициализация Датасетов и Dataloader-ов
# # train_dataset = MedicalImageDataset(...)
# # val_dataset = MedicalImageDataset(...)
#
# # Ячейка 4 (Code)
# # TODO: Инициализация простой модели (например, torchvision.models.resnet18)
# # model = ...
#
# # Ячейка 5 (Code)
# # TODO: Запуск обучения на 5-10 эпох
# # trainer = MedicalTrainer(...)
# # trainer.fit(epochs=5, save_dir="../weights/baseline.pt")
