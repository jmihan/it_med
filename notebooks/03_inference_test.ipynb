# %% [markdown]
# # Ячейка 1 (Markdown)
# ## 03. Тестирование инференса
# Цель: Проверить, что сохраненные веса успешно загружаются в классы-обертки из папки `models/` и выдают адекватный результат. Замер скорости.
#
# # Ячейка 2 (Code)
# import sys
# import time
# import cv2
# import matplotlib.pyplot as plt
# sys.path.append('..')
#
# # TODO: Импорт нужного класса модели
# # from models.classifier import ImageClassifier
# # from models.keypoint_detector import KeypointDetector
#
# # Ячейка 3 (Code)
# # TODO: Инициализация обертки
# # model = ImageClassifier(weights_path="../weights/baseline.pt")
# # print("Модель загружена!")
#
# # Ячейка 4 (Code)
# # TODO: Загрузка одной тестовой картинки
# # test_image = cv2.imread("../data/test/sample.jpg")
# # test_image = cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB)
#
# # Ячейка 5 (Code)
# # TODO: Замер времени (важно для понимания, потянет ли UI)
# # %%timeit
# # result = model.predict(test_image)
#
# # Ячейка 6 (Code)
# # TODO: Отрисовка результата на картинке
# # plt.imshow(test_image)
# # print(result)
